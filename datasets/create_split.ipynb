# %%
# !pip install transformers
# !pip install datasets

# !pip install -U PyYAML
# Out:
# Collecting transformers
#   Downloading transformers-4.9.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 8.1 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 63.1 MB/s
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.1)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 64.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 48.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.12 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.9.1
# Collecting datasets
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 7.4 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 57.4 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: huggingface-hub<0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.0.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.6.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 47.4 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Collecting tqdm>=4.42
#   Downloading tqdm-4.62.0-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 3.7 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.5.30)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: tqdm, xxhash, fsspec, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed datasets-1.11.0 fsspec-2021.7.0 tqdm-4.62.0 xxhash-2.0.2
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (5.4.1)

# %%
import pandas as pd
import yaml
import pathlib
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We want to get the fixed train/test split along with their success labels and genre labels. We then want to keep mind of the success distribution as well as the genre distribution for each success label in the test split.
#
#                           success                     failure
#                       /  /      .\. \             /  /      .\. \
#                      /   |      .|.  \           /   |      .|.  \
#                   crime drama   ... comedy     crime drama  ... comedy
#
# We then want to split the training data into a train split and val split by randomly removing some percentage of the books from the train split and putting it into the val split while keeping the distribution of success and genre labels the same as that of the test split.

# %%
yamlpath = '/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/train_test_split_goodreads.yaml'
class GoodreadsSplit:
  def __init__(self):
    self.book_ids = []
    self.success = []
    self.genres = []
  
  def append_to_lists(self, bid, s, g):
    self.book_ids.append(bid)
    self.success.append(s)
    self.genres.append(g)

  def to_df(self):
    df = pd.DataFrame({
        'book_ids': self.book_ids,
        'success': self.success,
        'genre': self.genres
      })
    return df

# %%
train_split = GoodreadsSplit()
test_split = GoodreadsSplit()

# %%
dataset_base = pathlib.Path('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text')

# %%
def get_labels_from_doc(doc):
  path = list(dataset_base.rglob(doc))[0]
  classStr = os.path.dirname(path).rsplit('/', 1)[1]
  genreStr = os.path.dirname(path).rsplit('/', 2)[1]
  return classStr, genreStr

with open(yamlpath) as file:
  documents = yaml.full_load(file)
  for doc in documents['train']:
    classStr, genreStr = get_labels_from_doc(doc)
    train_split.append_to_lists(doc, classStr, genreStr)

  for doc in documents['test']:
    classStr, genreStr = get_labels_from_doc(doc)
    test_split.append_to_lists(doc, classStr, genreStr)

# %%
print('train:',len(train_split.book_ids), "\ntest:", len(test_split.book_ids))
# Out:
# train: 694
# test: 290

# %%
694+290
# Out:
# 984

# %%
from glob import glob
result = []
for x in os.walk(dataset_base):
  for y in glob(os.path.join(x[0], '*.txt')):
    last_folder = pathlib.PurePath(y).parent.name
    if last_folder in ['success', 'failure']:
      result.append(y)

# %%
len(result)
# Out:
# 1003

# %% [markdown]
# The reason for the discrepancy between the number of books in yaml and the number of books found in the folder is that some books are listed twice if they belong to multiple genres..
# For simplicity's sake and the fact that it is only an issue for 19 books, we will ignore the fact that a book can have two genres

# %%
train_df = train_split.to_df()
test_df = test_split.to_df()

# %%
test_df
# Out:
#                                               book_ids  ...                          genre
# 0                           13724_the+frontiersmen.txt  ...                  Short_stories
# 1                                   4765_loyalties.txt  ...                          Drama
# 2                         23588_a+filbert+is+a+nut.txt  ...                  Short_stories
# 3                         18057_flower+of+the+dusk.txt  ...                   Love_stories
# 4                   109_renascence+and+other+poems.txt  ...                         Poetry
# ..                                                 ...  ...                            ...
# 285  24873_lucy+maud+montgomery+short+stories+1896+...  ...                  Short_stories
# 286         27391_the+mouse+and+the+christmas+cake.txt  ...                         Poetry
# 287                  3612_john+bull's+other+island.txt  ...                          Drama
# 288                      28164_the+big+bow+mystery.txt  ...  Detective_and_mystery_stories
# 289                           19750_the+waif+woman.txt  ...                  Short_stories
#
# [290 rows x 3 columns]

# %%
success_labels = ['failure', 'success']
genres = ['Detective_and_mystery_stories', 'Drama', 'Fiction', 'Historical_fiction', 'Love_stories', 'Poetry', 'Science_fiction', 'Short_stories']

test_distros = {'failure': {}, 'success': {}}
for s_label in success_labels:
  for genre in genres:
    cnt = test_df[(test_df.success == s_label) & (test_df.genre == genre)].shape[0]
    test_distros[s_label][genre] = cnt / 290

# %%
# for s_label in test_distros:
#   for genre in test_distros[s_label]:
#     test_distros[s_label][genre] /= 290

# %%
test_distros
# Out:
# {'failure': {'Detective_and_mystery_stories': 0.07241379310344828,
#   'Drama': 0.02413793103448276,
#   'Fiction': 0.034482758620689655,
#   'Historical_fiction': 0.017241379310344827,
#   'Love_stories': 0.013793103448275862,
#   'Poetry': 0.03103448275862069,
#   'Science_fiction': 0.05517241379310345,
#   'Short_stories': 0.10689655172413794},
#  'success': {'Detective_and_mystery_stories': 0.03793103448275862,
#   'Drama': 0.07931034482758621,
#   'Fiction': 0.07931034482758621,
#   'Historical_fiction': 0.05862068965517241,
#   'Love_stories': 0.05517241379310345,
#   'Poetry': 0.15172413793103448,
#   'Science_fiction': 0.034482758620689655,
#   'Short_stories': 0.1482758620689655}}

# %%
val_distros = {'failure': {}, 'success': {}}

# %%
total_test_samples = train_df.shape[0] * 0.2

# %%
for s_label in test_distros:
  for genre in test_distros[s_label]:
    val_distros[s_label][genre] = round(total_test_samples * test_distros[s_label][genre])

# %%
val_distros
# Out:
# {'failure': {'Detective_and_mystery_stories': 10,
#   'Drama': 3,
#   'Fiction': 5,
#   'Historical_fiction': 2,
#   'Love_stories': 2,
#   'Poetry': 4,
#   'Science_fiction': 8,
#   'Short_stories': 15},
#  'success': {'Detective_and_mystery_stories': 5,
#   'Drama': 11,
#   'Fiction': 11,
#   'Historical_fiction': 8,
#   'Love_stories': 8,
#   'Poetry': 21,
#   'Science_fiction': 5,
#   'Short_stories': 21}}

# %%
val_idx = pd.Int64Index([])

# %%
val_idx
# Out:
# Int64Index([], dtype='int64')

# %%
for s_label in success_labels:
  for genre in genres:
    num_samples = val_distros[s_label][genre]
    oy = train_df[(train_df.success == s_label) & (train_df.genre == genre)].sample(num_samples).index
    val_idx = val_idx.union(oy)

# %%
val_df = train_df.loc[val_idx]

# %%
train_df = train_df.drop(val_idx)

# %%
listdoc = {
    'train': train_df['book_ids'].tolist(),
    'val': val_df['book_ids'].tolist(),
    'test': test_df['book_ids'].tolist()
}

# %%
with open('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_preprocessed/trimmed_and_nered/train_test_val_80_20_split_goodreads.yaml', 'w') as f:
    yaml.dump(listdoc, f)

# %% [markdown]
# # Unused Code

# %%
yaml_books = train_split.book_ids + test_split.book_ids

# %%
yaml_books = set(yaml_books)

# %%
missing_books = []
for x in os.walk(dataset_base):
  for y in glob(os.path.join(x[0], '*.txt')):
    last_folder = pathlib.PurePath(y).parent.name
    if last_folder in ['success', 'failure']:
      if not os.path.basename(y) in yaml_books:
        missing_books.append(y)

# %%
missing_books
# Out:
# []

# %%
def get_labels_from_doc(doc):
  path = list(dataset_base.rglob(doc))
  if (len(path)>1):
    print(path)
  path = path[0]
  classStr = os.path.dirname(path).rsplit('/', 1)[1]
  genreStr = os.path.dirname(path).rsplit('/', 2)[1]
  return classStr, genreStr

with open(yamlpath) as file:
  documents = yaml.full_load(file)
  for doc in documents['train']:
    classStr, genreStr = get_labels_from_doc(doc)

  for doc in documents['test']:
    classStr, genreStr = get_labels_from_doc(doc)
# Out:
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/13707_twice+told+tales.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/success/13707_twice+told+tales.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/513_the+snow+image+and+other+stories.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/success/513_the+snow+image+and+other+stories.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Drama/failure/16659_translations+of+shakuntala+and+other+works.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Poetry/failure/16659_translations+of+shakuntala+and+other+works.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/5897_castle+richmond.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/5897_castle+richmond.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Poetry/failure/163_flower+fables.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/failure/163_flower+fables.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/1366_the+cloister+and+the+hearth.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/1366_the+cloister+and+the+hearth.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/12280_the+grandissimes.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/12280_the+grandissimes.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Detective_and_mystery_stories/success/3790_major+barbara.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Drama/success/3790_major+barbara.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/24985_comedies+of+courtship.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/success/24985_comedies+of+courtship.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/failure/4097_alice+of+old+vincennes.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/failure/4097_alice+of+old+vincennes.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/failure/16692_beyond+the+rocks+a+love+story.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/failure/16692_beyond+the+rocks+a+love+story.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/471_the+bride+of+lammermoor.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/471_the+bride+of+lammermoor.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Poetry/failure/715_the+moon+endureth+tales+and+fancies.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/failure/715_the+moon+endureth+tales+and+fancies.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Poetry/success/16578_the+kipling+reader+selections+from+the.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/success/16578_the+kipling+reader+selections+from+the.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Poetry/success/2381_actions+and+reactions.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/success/2381_actions+and+reactions.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/1457_mistress+wilding.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/1457_mistress+wilding.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Drama/success/14591_faust.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Poetry/success/14591_faust.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/success/840_lorna+doone+a+romance+of+exmoor.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Love_stories/success/840_lorna+doone+a+romance+of+exmoor.txt')]
# [PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Historical_fiction/failure/15868_the+man+without+a+country+and+other+tales.txt'), PosixPath('/content/drive/MyDrive/Thesis/BookSuccessPredictor/datasets/goodreads_maharjan_super/raw_text/Short_stories/failure/15868_the+man+without+a+country+and+other+tales.txt')]
